# %%
import pandas as pd

# %%
df = pd.read_csv("insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['smoker'] = df["smoker"].map({"yes":1,"no":0})
df["sex"]=df["sex"].map({"male":1,"female":0})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   int64
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   int64
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 83.6+ KB

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1337.000000  1337.000000  1337.000000  1337.000000  1337.000000
# mean     39.222139     0.504862    30.663452     1.095737     0.204936
# std      14.044333     0.500163     6.100468     1.205571     0.403806
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.290000     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.700000     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             charges
# count   1337.000000
# mean   13279.121487
# std    12110.359656
# min     1121.873900
# 25%     4746.344000
# 50%     9386.161300
# 75%    16657.717450
# max    63770.428010

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=df,x=df["age"], kde=True)
plt.title('Distribution of Contractor Age', fontsize=12)
plt.xlabel('Age', fontsize=10)
plt.ylabel('Frequency', fontsize=10) 
plt.show()

# %%
f= plt.figure(figsize=(12,6))

ax=f.add_subplot(121)
sns.histplot(df[(df.smoker == 1)]["charges"],color='b',ax=ax,kde=True)
ax.set_title('Distribution of charges for smokers')

ax=f.add_subplot(122)
sns.histplot(df[(df.smoker == 0)]["charges"],color='r',ax=ax,kde=True)
ax.set_title('Distribution of charges for non-smokers')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=df,x=df["children"], kde=True,hue='smoker')
plt.title('Distribution of Children', fontsize=12)
plt.xlabel('Age', fontsize=10)
plt.ylabel('Frequency', fontsize=10) 
plt.show()

# %%
sns.boxplot(data=df['bmi'])
plt.show()

# %%
sns.boxplot(data=df['age'])
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of bmi")
ax = sns.histplot(df["bmi"], color = 'c',kde=True)

# %%
sns.scatterplot(df,x="bmi",y="charges", color = 'c',hue='smoker')
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(df,x="age",y="charges", color = 'c',hue='smoker')
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
plt.figure(figsize=(12,5))
sns.lineplot(data=df,x=df["age"],y=df["children"], color='skyblue')
plt.title('Distribution of Contractor Age', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Children', fontsize=12)
plt.show()

# %%
sns.histplot(df[(df.children<3)]["charges"],color='c',kde=True)
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
sns.histplot(df['charges'], kde=True)
plt.title("Distribution of Target Variable (Y)")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder

# %%
X = df.drop(columns=['charges'])
y = df['charges']

# %%
import numpy as np

# %%
y_log = np.log1p(y) ## y_log = np.log(y + 1)

# %%
y_log
# Out:
# 0        9.734236
# 1        7.453882
# 2        8.400763
# 3        9.998137
# 4        8.260455
#           ...
# 1333     9.268755
# 1334     7.699381
# 1335     7.396847
# 1336     7.605365
# 1337    10.279948
# Name: charges, Length: 1337, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y_log, random_state = 42, test_size = 0.2)

# %%
X_train
# Out:
#       age  sex     bmi  children  smoker     region
# 1114   23    1  24.510         0       0  northeast
# 968    21    1  25.745         2       0  northeast
# 599    52    0  37.525         2       0  northwest
# 170    63    1  41.470         0       0  southeast
# 275    47    0  26.600         2       0  northeast
# ...   ...  ...     ...       ...     ...        ...
# 1096   51    0  34.960         2       1  northeast
# 1131   27    1  45.900         2       0  southwest
# 1295   20    1  22.000         1       0  southwest
# 861    38    0  28.000         3       0  southwest
# 1127   35    0  35.860         2       0  southeast
#
# [1069 rows x 6 columns]

# %% [markdown]
# ## Handling Outliers

# %%
def remove_outliers(X_train, y_train, column):
    Q1 = X_train[column].quantile(0.25)
    Q3 = X_train[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    mask = (X_train[column] >= lower_bound) & (X_train[column] <= upper_bound)
    
    return X_train[mask], y_train[mask]

# %%
X_train, y_train = remove_outliers(X_train, y_train, 'bmi')

# %% [markdown]
# ## Encoder

# %%
X_train_encoded = pd.get_dummies(X_train,drop_first=True,dtype=int)
X_test_encoded = pd.get_dummies(X_test,drop_first=True,dtype=int)

# %%
X_test_encoded = X_test_encoded.reindex(columns=X_train_encoded.columns, fill_value=0)

# %%
X_train_encoded
# Out:
#       age  sex     bmi  children  smoker  region_northwest  region_southeast  \
# 1114   23    1  24.510         0       0                 0                 0
# 968    21    1  25.745         2       0                 0                 0
# 599    52    0  37.525         2       0                 1                 0
# 170    63    1  41.470         0       0                 0                 1
# 275    47    0  26.600         2       0                 0                 0
# ...   ...  ...     ...       ...     ...               ...               ...
# 1096   51    0  34.960         2       1                 0                 0
# 1131   27    1  45.900         2       0                 0                 0
# 1295   20    1  22.000         1       0                 0                 0
# 861    38    0  28.000         3       0                 0                 0
# 1127   35    0  35.860         2       0                 0                 1
#
#       region_southwest
# ...

# %%
X_test_encoded
# Out:
#       age  sex     bmi  children  smoker  region_northwest  region_southeast  \
# 900    49    1  22.515         0       0                 0                 0
# 1064   29    0  25.600         4       0                 0                 0
# 1256   51    0  36.385         3       0                 1                 0
# 298    31    1  34.390         3       1                 1                 0
# 237    31    1  38.390         2       0                 0                 1
# ...   ...  ...     ...       ...     ...               ...               ...
# 534    64    1  40.480         0       0                 0                 1
# 542    63    0  36.300         0       0                 0                 1
# 760    22    0  34.580         2       0                 0                 0
# 1284   61    1  36.300         1       1                 0                 0
# 1285   47    0  24.320         0       0                 0                 0
#
#       region_southwest
# ...

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
num_features = ['age', 'bmi']

# %%
X_train_encoded[num_features] = scaler.fit_transform(X_train_encoded[num_features])

# %%
X_test_encoded[num_features] = scaler.transform(X_test_encoded[num_features])

# %%
X_train_scaled = X_train_encoded.copy()
X_test_scaled = X_test_encoded.copy()

# %%
X_train_scaled
# Out:
#            age  sex       bmi  children  smoker  region_northwest  \
# 1114 -1.159848    1 -1.006385         0       0                 0
# 968  -1.302928    1 -0.796445         2       0                 0
# 599   0.914809    0  1.206057         2       0                 1
# 170   1.701748    1  1.876674         0       0                 0
# 275   0.557110    0 -0.651103         2       0                 0
# ...        ...  ...       ...       ...     ...               ...
# 1096  0.843269    0  0.770028         2       1                 0
# 1131 -0.873689    1  2.629737         2       0                 0
# 1295 -1.374468    1 -1.433064         1       0                 0
# 861  -0.086750    0 -0.413114         3       0                 0
# 1127 -0.301369    0  0.923020         2       0                 0
#
#       region_southeast  region_southwest
# 1114                 0                 0
# 968                  0                 0
# 599                  0                 0
# ...

# %%
X_test_scaled
# Out:
#            age  sex       bmi  children  smoker  region_northwest  \
# 900   0.700189    1 -1.345519         0       0                 0
# 1064 -0.730609    0 -0.821094         4       0                 0
# 1256  0.843269    0  1.012266         3       0                 1
# 298  -0.587529    1  0.673133         3       1                 1
# 237  -0.587529    1  1.353099         2       0                 0
# ...        ...  ...       ...       ...     ...               ...
# 534   1.773288    1  1.708382         0       0                 0
# 542   1.701748    0  0.997817         0       0                 0
# 760  -1.231388    0  0.705431         2       0                 0
# 1284  1.558668    1  0.997817         1       1                 0
# 1285  0.557110    0 -1.038684         0       0                 0
#
#       region_southeast  region_southwest
# 900                  0                 0
# 1064                 0                 1
# 1256                 0                 0
# ...

# %% [markdown]
# ## Fitting Multiple Linear Regression Model

# %%
lr_model = LinearRegression()
lr_model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr = lr_model.predict(X_test_scaled)

# %%
y_pred_lr = np.expm1(y_pred_lr)
y_pred_lr
# Out:
# array([ 7593.89224049,  5797.30213443, 13631.72072911, 28895.23779023,
#         5517.16920118, 10030.91947325, 23201.48455124,  3030.15110814,
#         7784.68822891, 10631.29046802, 11520.13992648, 39755.04825943,
#        25395.56010671, 14932.72327129,  7689.08897961,  7938.91908134,
#         3273.14104458, 26194.60854416,  3890.35672752,  4453.90963819,
#         3119.4480558 , 26907.22815796, 11605.51597199, 26987.26326645,
#        25186.37207505,  4302.26170917, 40977.45401798, 53038.31256478,
#        10119.24325738, 13048.91624134,  5002.86623547,  9347.39930824,
#         2611.28439262, 11372.67562626, 55732.63189518, 10248.53784587,
#         4751.4764748 ,  5327.10380834, 34638.51090777,  7756.77728979,
#         4162.84596213, 36284.86820752, 40859.51767275, 10269.53470327,
#         8303.54837088,  3791.59881104,  3659.08396741,  7362.4444982 ,
#         4442.82307932,  6653.10250637,  4980.6284786 ,  7154.60824085,
# ...

# %%
y_test
# Out:
# 900      9.069912
# 1064     8.649951
# 1256     9.344674
# 298     10.564818
# 237      8.403846
#           ...
# 534      9.534748
# 542      9.538795
# 760      8.275569
# 1284    10.766480
# 1285     9.052009
# Name: charges, Length: 268, dtype: float64

# %%
y_test_original = np.expm1(y_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
print("🔹 Multiple Linear Regression:")
print(f"  - MAE: {mean_absolute_error(y_test_original, y_pred_lr):.2f}")
print(f"  - MSE: {mean_squared_error(y_test_original, y_pred_lr):.2f}")
print(f"  - R² Score: {r2_score(y_test_original, y_pred_lr):.2f}")
# Out:
# 🔹 Multiple Linear Regression:
#   - MAE: 3750.92
#   - MSE: 51000708.96
#   - R² Score: 0.72

# %% [markdown]
# ## Fitting KNN Regressor Model

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn_model = KNeighborsRegressor(n_neighbors=5)
knn_model.fit(X_train_scaled, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred_knn = knn_model.predict(X_test_scaled)
y_pred_knn = np.expm1(y_pred_knn)

# %%
print("\n🔹 KNN Regressor:")
print(f"  - MSE: {mean_squared_error(y_test_original, y_pred_knn):.2f}")
print(f"  - R² Score: {r2_score(y_test_original, y_pred_knn):.2f}")
# Out:
# 🔹 KNN Regressor:
#   - MSE: 87498032.16
#   - R² Score: 0.52

# %%
errors = y_test_original - y_pred_lr

# %%
np.mean(abs(errors))
# Out:
# np.float64(3750.9167852274595)

# %%
np.mean(errors**2)
# Out:
# np.float64(51000708.959890164)

# %%
np.sqrt(np.mean(errors**2))
# Out:
# np.float64(7141.478065491076)

# %%
y_test_original
# Out:
# 900      8688.85885
# 1064     5708.86700
# 1256    11436.73815
# 298     38746.35510
# 237      4463.20510
#            ...
# 534     13831.11520
# 542     13887.20400
# 760      3925.75820
# 1284    47403.88000
# 1285     8534.67180
# Name: charges, Length: 268, dtype: float64

# %%
errors = y_test_original - y_pred_lr

# %%
results_df = pd.DataFrame({
    'Actual': y_test_original,
    'Predicted': y_pred_lr,
    'Error': errors
})

# %%
results_df
# Out:
#            Actual     Predicted         Error
# 900    8688.85885   7593.892240   1094.966610
# 1064   5708.86700   5797.302134    -88.435134
# 1256  11436.73815  13631.720729  -2194.982579
# 298   38746.35510  28895.237790   9851.117310
# 237    4463.20510   5517.169201  -1053.964101
# ...           ...           ...           ...
# 534   13831.11520  14274.256572   -443.141372
# 542   13887.20400  14023.230652   -136.026652
# 760    3925.75820   4713.713635   -787.955435
# 1284  47403.88000  63547.362642 -16143.482642
# 1285   8534.67180   7835.876707    698.795093
#
# [268 rows x 3 columns]

# %%
import joblib
joblib.dump(lr_model, 'lr_model.joblib')
joblib.dump(knn_model, 'knn_model.joblib')
joblib.dump(scaler, 'scaler.joblib')
# Out:
# ['scaler.joblib']

# %%
joblib.dump(X_train_encoded.columns, 'feature_columns.joblib')
# Out:
# ['feature_columns.joblib']

# %%
feature_columns = joblib.load('feature_columns.joblib')
feature_columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region_northwest',
#        'region_southeast', 'region_southwest'],
#       dtype='object')

# %%
lr_model = joblib.load('lr_model.joblib')
knn_model = joblib.load('knn_model.joblib')
scaler = joblib.load('scaler.joblib')

# %%
new_data = {
    'age': 19,
    'sex': 'female',
    'bmi': 27.900,
    'children': 0,
    'smoker': 'yes',
    'region': 'southwest'
}

# %%
def predict(new_data):
    df = pd.DataFrame([new_data])
    df['smoker'] = df["smoker"].map({"yes":1,"no":0})
    df["sex"]=df["sex"].map({"male":1,"female":0})
    df = pd.get_dummies(df,drop_first=True,dtype=int)
    df = df.reindex(columns=feature_columns, fill_value=0)
    df[num_features] = scaler.transform(df[num_features])
    return np.expm1(lr_model.predict(df))

# %%
new_pred = predict(new_data)

# %%
new_pred
# Out:
# array([14736.7218351])
